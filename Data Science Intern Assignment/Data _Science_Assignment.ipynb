# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('sales_data.xlsx')
df.head()
# Out:
#    CustomerID  TOTAL_ORDERS   REVENUE  AVERAGE_ORDER_VALUE  CARRIAGE_REVENUE  \
# 0        22.0         124.0  11986.54                96.67            529.59
# 1        29.0          82.0  11025.96               134.46             97.92
# 2        83.0          43.0   7259.69               168.83            171.69
# 3        95.0          44.0   6992.27               158.92             92.82
# 4       124.0          55.0   6263.44               113.88            179.04
#
#    AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  AVGDAYSBETWEENORDERS  \
# 0             4.27       2016-12-30        2021-10-24                 14.19
# 1             1.19       2018-03-31        2021-10-24                 15.89
# 2             3.99       2017-11-30        2021-10-24                 33.12
# 3             2.11       2019-04-09        2021-10-24                 21.11
# 4             3.26       2020-10-23        2021-10-24                  6.65
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5001 entries, 0 to 5000
# Data columns (total 42 columns):
# CustomerID                   5000 non-null float64
# TOTAL_ORDERS                 5000 non-null float64
# REVENUE                      5000 non-null float64
# AVERAGE_ORDER_VALUE          5000 non-null float64
# CARRIAGE_REVENUE             5000 non-null float64
# AVERAGESHIPPING              5000 non-null float64
# FIRST_ORDER_DATE             5000 non-null datetime64[ns]
# LATEST_ORDER_DATE            5000 non-null datetime64[ns]
# AVGDAYSBETWEENORDERS         5000 non-null float64
# DAYSSINCELASTORDER           5000 non-null float64
# MONDAY_ORDERS                5001 non-null int64
# TUESDAY_ORDERS               5001 non-null int64
# WEDNESDAY_ORDERS             5001 non-null int64
# THURSDAY_ORDERS              5001 non-null int64
# FRIDAY_ORDERS                5001 non-null int64
# SATURDAY_ORDERS              5001 non-null int64
# ...

# %%
df.describe().round(2)
# Out:
#        CustomerID  TOTAL_ORDERS   REVENUE  AVERAGE_ORDER_VALUE  \
# count     5000.00       5000.00   5000.00              5000.00
# mean     40709.23         12.87   1681.52               136.54
# std      49949.85         12.68   1998.62                91.65
# min          1.00          1.00     38.50                10.68
# 25%       1687.50          3.00    315.10                83.02
# 50%      13765.00          8.00    966.72               113.16
# 75%      71891.50         20.00   2493.07               160.27
# max     277160.00        156.00  34847.40              1578.88
#
#        CARRIAGE_REVENUE  AVERAGESHIPPING  AVGDAYSBETWEENORDERS  \
# count           5000.00          5000.00               5000.00
# mean              46.04             3.59                163.16
# std               47.88             2.02                259.70
# min                0.00             0.00                  0.00
# 25%                9.98             2.50                 21.67
# ...

# %%
# Checking Null values in Train Set
df.isnull().sum()
# Out:
# CustomerID                      1
# TOTAL_ORDERS                    1
# REVENUE                         1
# AVERAGE_ORDER_VALUE             1
# CARRIAGE_REVENUE                1
# AVERAGESHIPPING                 1
# FIRST_ORDER_DATE                1
# LATEST_ORDER_DATE               1
# AVGDAYSBETWEENORDERS            1
# DAYSSINCELASTORDER              1
# MONDAY_ORDERS                   0
# TUESDAY_ORDERS                  0
# WEDNESDAY_ORDERS                0
# THURSDAY_ORDERS                 0
# FRIDAY_ORDERS                   0
# SATURDAY_ORDERS                 0
# SUNDAY_ORDERS                   0
# MONDAY_REVENUE                  0
# TUESDAY_REVENUE                 0
# WEDNESDAY_REVENUE               0
# THURSDAY_REVENUE                0
# FRIDAY_REVENUE                  0
# SATURDAY_REVENUE                0
# SUNDAY_REVENUE                  0
# WEEK1_DAY01_DAY07_ORDERS        1
# WEEK2_DAY08_DAY15_ORDERS        1
# WEEK3_DAY16_DAY23_ORDERS        1
# ...

# %%
df.shape
# Out:
# (5001, 42)

# %%
#Filling the Null values
df['TIME_1801_2359_REVENUE'].fillna(value=df['TIME_1801_2359_REVENUE'].mean(),inplace=True)
df['TIME_1200_1800_REVENUE'].fillna(value=df['TIME_1200_1800_REVENUE'].mean(),inplace=True)
df['TIME_0601_1200_REVENUE'].fillna(value=df['TIME_0601_1200_REVENUE'].mean(),inplace=True)
df['TIME_1801_2359_ORDERS'].fillna(value=df['TIME_1801_2359_ORDERS'].mean(),inplace=True)
df['TIME_1200_1800_ORDERS'].fillna(value=df['TIME_1200_1800_ORDERS'].mean(),inplace=True)
df['TIME_0601_1200_ORDERS'].fillna(value=df['TIME_0601_1200_ORDERS'].mean(),inplace=True)
df['TIME_0000_0600_ORDERS'].fillna(value=df['TIME_0000_0600_ORDERS'].mean(),inplace=True)
df['TIME_0000_0600_REVENUE'].fillna(value=df['TIME_0000_0600_REVENUE'].mean(),inplace=True)
df['WEEK1_DAY01_DAY07_ORDERS'].fillna(value=df['WEEK1_DAY01_DAY07_ORDERS'].mean(),inplace=True)
df['WEEK2_DAY08_DAY15_ORDERS'].fillna(value=df['WEEK2_DAY08_DAY15_ORDERS'].mean(),inplace=True)
df['WEEK3_DAY16_DAY23_ORDERS'].fillna(value=df['WEEK3_DAY16_DAY23_ORDERS'].mean(),inplace=True)
df['WEEK4_DAY24_DAY31_ORDERS'].fillna(value=df['WEEK4_DAY24_DAY31_ORDERS'].mean(),inplace=True)
df['WEEK1_DAY01_DAY07_REVENUE'].fillna(value=df['WEEK1_DAY01_DAY07_REVENUE'].mean(),inplace=True)
df['WEEK2_DAY08_DAY15_REVENUE'].fillna(value=df['WEEK2_DAY08_DAY15_REVENUE'].mean(),inplace=True)
df['WEEK3_DAY16_DAY23_REVENUE'].fillna(value=df['WEEK3_DAY16_DAY23_REVENUE'].mean(),inplace=True)
df['WEEK4_DAY24_DAY31_REVENUE'].fillna(value=df['WEEK4_DAY24_DAY31_REVENUE'].mean(),inplace=True)
df['CustomerID'].fillna(value=df['CustomerID'].mean(),inplace=True)
df['TOTAL_ORDERS'].fillna(value=df['TOTAL_ORDERS'].mean(),inplace=True)
df['REVENUE'].fillna(value=df['REVENUE'].mean(),inplace=True)
df['AVERAGE_ORDER_VALUE'].fillna(value=df['AVERAGE_ORDER_VALUE'].mean(),inplace=True)
df['CARRIAGE_REVENUE'].fillna(value=df['CARRIAGE_REVENUE'].mean(),inplace=True)
df['AVERAGESHIPPING'].fillna(value=df['AVERAGESHIPPING'].mean(),inplace=True)
df['FIRST_ORDER_DATE'].fillna(value=df['FIRST_ORDER_DATE'].mean(),inplace=True)
df['LATEST_ORDER_DATE'].fillna(value=df['LATEST_ORDER_DATE'].mean(),inplace=True)
df['AVGDAYSBETWEENORDERS'].fillna(value=df['AVGDAYSBETWEENORDERS'].mean(),inplace=True)
df['DAYSSINCELASTORDER'].fillna(value=df['DAYSSINCELASTORDER'].mean(),inplace=True)

#Filling the Null values in 'Outlet_Size' column with "Unknown"
df['Unnamed: 41'].fillna(value='Unknown',inplace=True)
df['Unnamed: 40'].fillna(value='Unknown',inplace=True)

# %%
df.isnull().sum()
# Out:
# CustomerID                   0
# TOTAL_ORDERS                 0
# REVENUE                      0
# AVERAGE_ORDER_VALUE          0
# CARRIAGE_REVENUE             0
# AVERAGESHIPPING              0
# FIRST_ORDER_DATE             0
# LATEST_ORDER_DATE            0
# AVGDAYSBETWEENORDERS         0
# DAYSSINCELASTORDER           0
# MONDAY_ORDERS                0
# TUESDAY_ORDERS               0
# WEDNESDAY_ORDERS             0
# THURSDAY_ORDERS              0
# FRIDAY_ORDERS                0
# SATURDAY_ORDERS              0
# SUNDAY_ORDERS                0
# MONDAY_REVENUE               0
# TUESDAY_REVENUE              0
# WEDNESDAY_REVENUE            0
# THURSDAY_REVENUE             0
# FRIDAY_REVENUE               0
# SATURDAY_REVENUE             0
# SUNDAY_REVENUE               0
# WEEK1_DAY01_DAY07_ORDERS     0
# WEEK2_DAY08_DAY15_ORDERS     0
# WEEK3_DAY16_DAY23_ORDERS     0
# WEEK4_DAY24_DAY31_ORDERS     0
# WEEK1_DAY01_DAY07_REVENUE    0
# WEEK2_DAY08_DAY15_REVENUE    0
# ...

# %%
df['TOTAL_ORDERS'].value_counts()
import numpy as np
import matplotlib.pyplot as plt
plt.bar(df['TOTAL_ORDERS'].value_counts().index, df['TOTAL_ORDERS'].value_counts(), width=2.0, bottom=None, align='center', data=df)
plt.title('TOTAL_ORDERS')
plt.xticks(rotation='vertical')
plt.xlabel('TOTAL_ORDERS_DISTRIBUTION')
plt.ylabel('Frequency')
print('Item_Type:\n',df['TOTAL_ORDERS'].value_counts())
# Out:
# Item_Type:
#  2.0      560
# 3.0      509
# 1.0      366
# 4.0      360
# 5.0      238
#         ...
# 82.0       1
# 83.0       1
# 65.0       1
# 128.0      1
# 124.0      1
# Name: TOTAL_ORDERS, Length: 86, dtype: int64

# %%
df.nunique()
# Out:
# CustomerID                   5001
# TOTAL_ORDERS                   86
# REVENUE                      4636
# AVERAGE_ORDER_VALUE          4114
# CARRIAGE_REVENUE             1176
# AVERAGESHIPPING               568
# FIRST_ORDER_DATE             1929
# LATEST_ORDER_DATE             208
# AVGDAYSBETWEENORDERS         3564
# DAYSSINCELASTORDER            208
# MONDAY_ORDERS                  20
# TUESDAY_ORDERS                 23
# WEDNESDAY_ORDERS               23
# THURSDAY_ORDERS                24
# FRIDAY_ORDERS                  25
# SATURDAY_ORDERS                25
# SUNDAY_ORDERS                  24
# MONDAY_REVENUE               2152
# TUESDAY_REVENUE              2202
# WEDNESDAY_REVENUE            2263
# THURSDAY_REVENUE             2583
# FRIDAY_REVENUE               2379
# SATURDAY_REVENUE             2141
# SUNDAY_REVENUE               2574
# WEEK1_DAY01_DAY07_ORDERS       28
# WEEK2_DAY08_DAY15_ORDERS       35
# WEEK3_DAY16_DAY23_ORDERS       34
# ...

# %%
df.head()
# Out:
#    CustomerID  TOTAL_ORDERS   REVENUE  AVERAGE_ORDER_VALUE  CARRIAGE_REVENUE  \
# 0        22.0         124.0  11986.54                96.67            529.59
# 1        29.0          82.0  11025.96               134.46             97.92
# 2        83.0          43.0   7259.69               168.83            171.69
# 3        95.0          44.0   6992.27               158.92             92.82
# 4       124.0          55.0   6263.44               113.88            179.04
#
#    AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  AVGDAYSBETWEENORDERS  \
# 0             4.27       2016-12-30        2021-10-24                 14.19
# 1             1.19       2018-03-31        2021-10-24                 15.89
# 2             3.99       2017-11-30        2021-10-24                 33.12
# 3             2.11       2019-04-09        2021-10-24                 21.11
# 4             3.26       2020-10-23        2021-10-24                  6.65
#
# ...

# %%
df.groupby('WEEK1_DAY01_DAY07_ORDERS').REVENUE.sum().plot(kind='bar', title='Best Day Of the Week To Sell')
plt.show()

# %%
df.groupby('TOTAL_ORDERS').monetary.sum().plot(kind='bar', title='total orders To Sell')
plt.show()

# %%
df.describe()
# Out:
#           CustomerID  TOTAL_ORDERS       REVENUE  AVERAGE_ORDER_VALUE  \
# count    5001.000000   5001.000000   5001.000000          5001.000000
# mean    40709.227800     12.870400   1681.523840           136.537378
# std     49944.852782     12.678612   1998.418806            91.642403
# min         1.000000      1.000000     38.500000            10.680000
# 25%      1689.000000      3.000000    315.130000            83.030000
# 50%     13766.000000      8.000000    966.750000           113.170000
# 75%     71872.000000     20.000000   2492.540000           160.270000
# max    277160.000000    156.000000  34847.400000          1578.880000
#
#        CARRIAGE_REVENUE  AVERAGESHIPPING  AVGDAYSBETWEENORDERS  \
# count       5001.000000      5001.000000           5001.000000
# mean          46.036376         3.592574            163.159618
# std           47.874438         2.021158            259.673525
# min            0.000000         0.000000              0.000000
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.hist(bins=50, figsize=(30,25))
plt.show()

# %%
cormat = df.corr()
round(cormat,2)
# Out:
#                            CustomerID  TOTAL_ORDERS  REVENUE  \
# CustomerID                       1.00         -0.61    -0.56
# TOTAL_ORDERS                    -0.61          1.00     0.77
# REVENUE                         -0.56          0.77     1.00
# AVERAGE_ORDER_VALUE             -0.23         -0.07     0.37
# CARRIAGE_REVENUE                -0.58          0.88     0.66
# AVERAGESHIPPING                  0.03         -0.01    -0.05
# AVGDAYSBETWEENORDERS             0.28         -0.31    -0.26
# DAYSSINCELASTORDER               0.38         -0.26    -0.20
# MONDAY_ORDERS                   -0.01          0.01     0.01
# TUESDAY_ORDERS                  -0.01          0.02     0.01
# WEDNESDAY_ORDERS                -0.01          0.02     0.01
# THURSDAY_ORDERS                 -0.01          0.01     0.01
# FRIDAY_ORDERS                   -0.01          0.01     0.01
# SATURDAY_ORDERS                 -0.01          0.02     0.01
# ...

# %%
print (df.corr())
# Out:
#                            CustomerID  TOTAL_ORDERS   REVENUE  \
# CustomerID                   1.000000     -0.608092 -0.556489
# TOTAL_ORDERS                -0.608092      1.000000  0.771996
# REVENUE                     -0.556489      0.771996  1.000000
# AVERAGE_ORDER_VALUE         -0.226023     -0.065208  0.366302
# CARRIAGE_REVENUE            -0.576043      0.875733  0.655447
# AVERAGESHIPPING              0.025649     -0.007855 -0.048932
# AVGDAYSBETWEENORDERS         0.279182     -0.311838 -0.257746
# DAYSSINCELASTORDER           0.375343     -0.256272 -0.197782
# MONDAY_ORDERS               -0.009141      0.014389  0.011471
# TUESDAY_ORDERS              -0.009283      0.015042  0.012248
# WEDNESDAY_ORDERS            -0.009143      0.015084  0.011692
# THURSDAY_ORDERS             -0.006058      0.011891  0.009129
# FRIDAY_ORDERS               -0.009323      0.014832  0.011072
# SATURDAY_ORDERS             -0.009248      0.015238  0.011186
# ...

# %%
#Annual Revenue of data
plt.figure(figsize=(9,6))
df.groupby(['CustomerID'])['TOTAL_ORDERS'].sum().plot(kind='barh')
plt.xlabel('TOTAL_ORDERS',size=12)
plt.ylabel('CustomerID',size=12)
plt.title('Annual Revenue',size=20)
plt.show()

# %%
df.head()
# Out:
#    CustomerID  TOTAL_ORDERS   REVENUE  AVERAGE_ORDER_VALUE  CARRIAGE_REVENUE  \
# 0        22.0         124.0  11986.54                96.67            529.59
# 1        29.0          82.0  11025.96               134.46             97.92
# 2        83.0          43.0   7259.69               168.83            171.69
# 3        95.0          44.0   6992.27               158.92             92.82
# 4       124.0          55.0   6263.44               113.88            179.04
#
#    AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  AVGDAYSBETWEENORDERS  \
# 0             4.27       2016-12-30        2021-10-24                 14.19
# 1             1.19       2018-03-31        2021-10-24                 15.89
# 2             3.99       2017-11-30        2021-10-24                 33.12
# 3             2.11       2019-04-09        2021-10-24                 21.11
# 4             3.26       2020-10-23        2021-10-24                  6.65
#
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'TOTAL_ORDERS', 'REVENUE', 'AVERAGE_ORDER_VALUE',
#        'CARRIAGE_REVENUE', 'AVERAGESHIPPING', 'FIRST_ORDER_DATE',
#        'LATEST_ORDER_DATE', 'AVGDAYSBETWEENORDERS', 'DAYSSINCELASTORDER',
#        'MONDAY_ORDERS', 'TUESDAY_ORDERS', 'WEDNESDAY_ORDERS',
#        'THURSDAY_ORDERS', 'FRIDAY_ORDERS', 'SATURDAY_ORDERS', 'SUNDAY_ORDERS',
#        'MONDAY_REVENUE', 'TUESDAY_REVENUE', 'WEDNESDAY_REVENUE',
#        'THURSDAY_REVENUE', 'FRIDAY_REVENUE', 'SATURDAY_REVENUE',
#        'SUNDAY_REVENUE', 'WEEK1_DAY01_DAY07_ORDERS',
#        'WEEK2_DAY08_DAY15_ORDERS', 'WEEK3_DAY16_DAY23_ORDERS',
#        'WEEK4_DAY24_DAY31_ORDERS', 'WEEK1_DAY01_DAY07_REVENUE',
#        'WEEK2_DAY08_DAY15_REVENUE', 'WEEK3_DAY16_DAY23_REVENUE',
#        'WEEK4_DAY24_DAY31_REVENUE', 'TIME_0000_0600_ORDERS',
#        'TIME_0601_1200_ORDERS', 'TIME_1200_1800_ORDERS',
#        'TIME_1801_2359_ORDERS', 'TIME_0000_0600_REVENUE',
#        'TIME_0601_1200_REVENUE', 'TIME_1200_1800_REVENUE',
# ...

# %%
import datetime as dt #for datetime transformation

df['FIRST_ORDER_DATE'] = pd.to_datetime(df['LATEST_ORDER_DATE'])

# Calculate Recency, Frequency and Monetary value for each customer
present = df['FIRST_ORDER_DATE'].max() + dt.timedelta(days=1) #latest date in the data set
rfm = df.groupby(['CustomerID']).agg({
    'FIRST_ORDER_DATE': lambda x: (present - x.max()).days,
    'CustomerID': 'count',
    'TOTAL_ORDERS':'sum'})

#Renaming the columns
rfm.rename(columns={'FIRST_ORDER_DATE': 'Recency',
                   'CustomerID': 'Frequency',
                   'TOTAL_ORDERS': 'Monetary'}, inplace=True)

# %%
#histogram for Recency
rfm.hist(column='Recency')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C11CB035C8>]],
#       dtype=object)

# %%
#histogram for Frequency
rfm.hist(column='Frequency')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C11CFCCA88>]],
#       dtype=object)

# %%
#histogram for Monetary
rfm.hist(column='Monetary')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C12319BFC8>]],
#       dtype=object)

# %%
#boxplot to check outliers
rfm.boxplot()

# %%
rfm.head()
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 1.0              53          1      61.0
# 2.0              94          1      59.0
# 3.0              53          1      53.0
# 4.0               5          1      84.0
# 5.0             130          1      26.0

# %%
df.columns
# Out:
# Index(['CustomerID', 'TOTAL_ORDERS', 'REVENUE', 'AVERAGE_ORDER_VALUE',
#        'CARRIAGE_REVENUE', 'AVERAGESHIPPING', 'FIRST_ORDER_DATE',
#        'LATEST_ORDER_DATE', 'AVGDAYSBETWEENORDERS', 'DAYSSINCELASTORDER',
#        'MONDAY_ORDERS', 'TUESDAY_ORDERS', 'WEDNESDAY_ORDERS',
#        'THURSDAY_ORDERS', 'FRIDAY_ORDERS', 'SATURDAY_ORDERS', 'SUNDAY_ORDERS',
#        'MONDAY_REVENUE', 'TUESDAY_REVENUE', 'WEDNESDAY_REVENUE',
#        'THURSDAY_REVENUE', 'FRIDAY_REVENUE', 'SATURDAY_REVENUE',
#        'SUNDAY_REVENUE', 'WEEK1_DAY01_DAY07_ORDERS',
#        'WEEK2_DAY08_DAY15_ORDERS', 'WEEK3_DAY16_DAY23_ORDERS',
#        'WEEK4_DAY24_DAY31_ORDERS', 'WEEK1_DAY01_DAY07_REVENUE',
#        'WEEK2_DAY08_DAY15_REVENUE', 'WEEK3_DAY16_DAY23_REVENUE',
#        'WEEK4_DAY24_DAY31_REVENUE', 'TIME_0000_0600_ORDERS',
#        'TIME_0601_1200_ORDERS', 'TIME_1200_1800_ORDERS',
#        'TIME_1801_2359_ORDERS', 'TIME_0000_0600_REVENUE',
#        'TIME_0601_1200_REVENUE', 'TIME_1200_1800_REVENUE',
# ...

# %%
import numpy as np
import pandas as pd
import math
from datetime import timedelta, datetime
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use("seaborn")
plt.rcParams["figure.figsize"] = (20, 5)

# %%
plt.style.use('ggplot')
plt.title('Units sold per week')
plt.ylabel('REVENUE')
plt.xlabel('FIRST_ORDER_DATE');
df['REVENUE'].plot(figsize=(20,5), c='dodgerblue');

# %%
plt.style.use('ggplot')
plt.title('Units sold per week')
plt.ylabel('REVENUE')
plt.xlabel('LATEST_ORDER_DATE');
df['REVENUE'].plot(figsize=(20,5), c='dodgerblue');

# %%
df.rename({'REVENUE': 'monetary'}, axis="columns", inplace=True)
df.head()
# Out:
#    CustomerID  TOTAL_ORDERS  monetary  AVERAGE_ORDER_VALUE  CARRIAGE_REVENUE  \
# 0        22.0         124.0  11986.54                96.67            529.59
# 1        29.0          82.0  11025.96               134.46             97.92
# 2        83.0          43.0   7259.69               168.83            171.69
# 3        95.0          44.0   6992.27               158.92             92.82
# 4       124.0          55.0   6263.44               113.88            179.04
#
#    AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  AVGDAYSBETWEENORDERS  \
# 0             4.27       2021-10-24        2021-10-24                 14.19
# 1             1.19       2021-10-24        2021-10-24                 15.89
# 2             3.99       2021-10-24        2021-10-24                 33.12
# 3             2.11       2021-10-24        2021-10-24                 21.11
# 4             3.26       2021-10-24        2021-10-24                  6.65
#
# ...

# %%
print('monetary from {} to {}'.format(df['FIRST_ORDER_DATE'].min(),
                                    df['FIRST_ORDER_DATE'].max()))
# Out:
# monetary from 2021-04-01 00:00:00 to 2021-10-24 00:00:00

# %%
print('monetary from {} to {}'.format(df['LATEST_ORDER_DATE'].min(),
                                    df['LATEST_ORDER_DATE'].max()))
# Out:
# monetary from 2021-04-01 00:00:00 to 2021-10-24 00:00:00

# %%
#Let's focus on sales from last 365 days since most recent date

period = 365
date_N_days_ago = df['FIRST_ORDER_DATE'].max() - timedelta(days=period)

# %%
# We remove the rows with dates older than 365 days ago

df = df[df['FIRST_ORDER_DATE']> date_N_days_ago]

# %%
df.reset_index(drop=True, inplace=True)

# %%
df.head()
# Out:
#    CustomerID  TOTAL_ORDERS  monetary  AVERAGE_ORDER_VALUE  CARRIAGE_REVENUE  \
# 0        22.0         124.0  11986.54                96.67            529.59
# 1        29.0          82.0  11025.96               134.46             97.92
# 2        83.0          43.0   7259.69               168.83            171.69
# 3        95.0          44.0   6992.27               158.92             92.82
# 4       124.0          55.0   6263.44               113.88            179.04
#
#    AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  AVGDAYSBETWEENORDERS  \
# 0             4.27       2021-10-24        2021-10-24                 14.19
# 1             1.19       2021-10-24        2021-10-24                 15.89
# 2             3.99       2021-10-24        2021-10-24                 33.12
# 3             2.11       2021-10-24        2021-10-24                 21.11
# 4             3.26       2021-10-24        2021-10-24                  6.65
#
# ...

# %%
#barplot of countries by total sales
fig,ax =plt.subplots(figsize=(10,6))
df.FIRST_ORDER_DATE.value_counts().plot(kind='bar')
plt.xlabel('FIRST_ORDER_DATE',size=12)
plt.ylabel('monetary',size=12)
plt.title('FIRST_ORDER_DATE by monetary',size=20)
ticks = plt.setp(ax.get_xticklabels(),rotation=290,size =10)
plt.show()

# %%
df.head()
# Out:
#    CustomerID  TOTAL_ORDERS  monetary  AVERAGE_ORDER_VALUE  CARRIAGE_REVENUE  \
# 0        22.0         124.0  11986.54                96.67            529.59
# 1        29.0          82.0  11025.96               134.46             97.92
# 2        83.0          43.0   7259.69               168.83            171.69
# 3        95.0          44.0   6992.27               158.92             92.82
# 4       124.0          55.0   6263.44               113.88            179.04
#
#    AVERAGESHIPPING FIRST_ORDER_DATE LATEST_ORDER_DATE  AVGDAYSBETWEENORDERS  \
# 0             4.27       2021-10-24        2021-10-24                 14.19
# 1             1.19       2021-10-24        2021-10-24                 15.89
# 2             3.99       2021-10-24        2021-10-24                 33.12
# 3             2.11       2021-10-24        2021-10-24                 21.11
# 4             3.26       2021-10-24        2021-10-24                  6.65
#
# ...

# %%
df['FIRST_ORDER_DATE'] = pd.to_datetime(df['FIRST_ORDER_DATE'])

# Calculate Recency, Frequency and Monetary value for each customer
present = df['FIRST_ORDER_DATE'].max() + dt.timedelta(days=1) #latest date in the data set
rfm = df.groupby(['CustomerID']).agg({
    'FIRST_ORDER_DATE': lambda x: (present - x.max()).days,
    'TOTAL_ORDERS': 'count',
    'monetary':'sum'})

#Renaming the columns
rfm.rename(columns={'FIRST_ORDER_DATE': 'Recency',
                   'TOTAL_ORDERS': 'Frequency',
                   'monetary': 'Monetary'}, inplace=True)

# %%
#histogram for Recency
rfm.hist(column='Recency')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C11F2F85C8>]],
#       dtype=object)

# %%
#histogram for Frequency
rfm.hist(column='Frequency')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C11F321248>]],
#       dtype=object)

# %%
#histogram for Monetary
rfm.hist(column='Monetary')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C11F395908>]],
#       dtype=object)

# %%
#boxplot to check outliers
rfm.boxplot()

# %%
rfm_clean = rfm[rfm['Monetary']<5000]
rfm_clean.boxplot()

# %%
rfm_clean.hist(column='Recency')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C142847748>]],
#       dtype=object)

# %%
#histogram for Frequency
rfm_clean.hist(column='Frequency')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C142E9A988>]],
#       dtype=object)

# %%
rfm_clean.hist(column='Monetary')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001C142E6A248>]],
#       dtype=object)

# %%
#uncleaned data
X = rfm

# %%
# Choose number of Clusters using the elbow method
from sklearn.cluster import KMeans
# start with 10 number of clusters
wcss = []
for i in range(1,10):
    kmeans = KMeans(n_clusters =i, init = 'k-means++', max_iter =300, n_init =10, random_state =0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,10), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Fitting K Means to the Datatset using k = 2 based on elbow methods
kmeans = KMeans(n_clusters = 2)
y_kmeans = kmeans.fit_predict(X)

# %%
#add new column Custer_ID in uncleaned rfm dataframe
rfm['Cluster_ID'] = y_kmeans

# %%
import seaborn as sns

# %%
# Create a plot for frequency vs monetary 
facet = sns.lmplot(data=X, x='Frequency', y='Monetary', hue='Cluster_ID', 
                   fit_reg=False, legend=True, legend_out=True)

# %%
# Create a plot for monetary and recency
facet2 = sns.lmplot(data=X, x='Recency', y='Monetary', hue='Cluster_ID', 
                   fit_reg=False, legend=True, legend_out=True)

# %%
#rfm clean data
X1 = rfm_clean

# %%
# Choose number of Clusters using the elbow method
from sklearn.cluster import KMeans
# start with 10 number of clusters
wcss = []
for i in range(1,10):
    kmeans = KMeans(n_clusters =i, init = 'k-means++', max_iter =300, n_init =10, random_state =0)
    kmeans.fit(X1)
    wcss.append(kmeans.inertia_)
plt.plot(range(1,10), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Fitting K Means to the Datatset using k = 2 based on elbow method
kmeans = KMeans(n_clusters = 2)
y_kmeans = kmeans.fit_predict(X1)

# %%
#add column Cluster_ID in rfm_clean dataframe
rfm_clean['Cluster_ID'] = y_kmeans
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Create a plot for frequency vs monetary 
facet = sns.lmplot(data=X1, x='Frequency', y='Monetary', hue='Cluster_ID', 
                   fit_reg=False, legend=True, legend_out=True)

# %%
# Create a plot for monetary and recency
facet2 = sns.lmplot(data=X1, x='Recency', y='Monetary', hue='Cluster_ID', 
                   fit_reg=False, legend=True, legend_out=True)

# %%
rfm_clean.head()
# Out:
#             Recency  Frequency  Monetary  Cluster_ID
# CustomerID
# 252.0           141          1   4993.54           1
# 253.0            21          1   4984.75           1
# 254.0            56          1   4982.03           1
# 255.0           129          1   4981.15           1
# 256.0            26          1   4971.71           1

# %%
quantil = rfm_clean.quantile(q=[0.25,0.50,0.75])
print(quantil)
# Out:
#       Recency  Frequency   Monetary  Cluster_ID
# 0.25      6.0        1.0   301.6150         0.0
# 0.50     70.0        1.0   848.9400         0.0
# 0.75    177.0        1.0  2177.9475         1.0

# %%
# Convert quantil into dict to access each value

quantil = quantil.to_dict()
print(quantil)
# Out:
# {'Recency': {0.25: 6.0, 0.5: 70.0, 0.75: 177.0}, 'Frequency': {0.25: 1.0, 0.5: 1.0, 0.75: 1.0}, 'Monetary': {0.25: 301.615, 0.5: 848.94, 0.75: 2177.9475}, 'Cluster_ID': {0.25: 0.0, 0.5: 0.0, 0.75: 1.0}}

# %%
def RecencyPoints(y,rfm,q):
  if y<=q[rfm][0.25]:
    return 4
  elif y<=q[rfm][0.50]:
    return 3
  elif y<=q[rfm][0.75]:
    return 2
  else:
    return 1

def Freq_MonetaryPoints(y,rfm,q):
    if y <= q[rfm][0.25]:
        return 1
    elif y <= q[rfm][0.50]:
        return 2
    elif y <= q[rfm][0.75]: 
        return 3
    else:
        return 4

rfm_segment = rfm_clean.copy()
rfm_segment['Recency_Quartile'] = rfm_segment['Recency'].apply(RecencyPoints,args=('Recency',quantil,))
rfm_segment['Frequency_Quartile'] = rfm_segment['Frequency'].apply(Freq_MonetaryPoints,args=('Frequency',quantil,))
rfm_segment['Monetary_Quartile'] = rfm_segment['Monetary'].apply(Freq_MonetaryPoints,args=('Monetary',quantil,))
rfm_segment.head()
# Out:
#             Recency  Frequency  Monetary  Cluster_ID  Recency_Quartile  \
# CustomerID
# 252.0           141          1   4993.54           1                 2
# 253.0            21          1   4984.75           1                 3
# 254.0            56          1   4982.03           1                 3
# 255.0           129          1   4981.15           1                 2
# 256.0            26          1   4971.71           1                 3
#
#             Frequency_Quartile  Monetary_Quartile
# CustomerID
# 252.0                        1                  4
# 253.0                        1                  4
# 254.0                        1                  4
# 255.0                        1                  4
# 256.0                        1                  4

# %%
rfm_segment['RFMPoints'] = rfm_segment.Recency_Quartile.map(str)+rfm_segment.Frequency_Quartile.map(str)+rfm_segment.Monetary_Quartile.map(str)
print(rfm_segment['RFMPoints'])
# Out:
# CustomerID
# 252.0       214
# 253.0       314
# 254.0       314
# 255.0       214
# 256.0       314
#            ...
# 248709.0    311
# 248710.0    211
# 259042.0    211
# 266024.0    211
# 277160.0    311
# Name: RFMPoints, Length: 4750, dtype: object

# %%
customer_dict = {'champions':'414','Potential customers':'314','need attention':'213'}

# %%
 dict_segment = dict(zip( customer_dict.values(),customer_dict.keys()))

rfm_segment['Segment'] = rfm_segment.RFMPoints.map(lambda x:dict_segment.get(x))
rfm_segment.Segment.fillna('others',inplace = True)
rfm_segment.sample(10)
# Out:
#             Recency  Frequency  Monetary  Cluster_ID  Recency_Quartile  \
# CustomerID
# 639.0            38          1   3616.59           1                 3
# 12835.0          66          1   1003.32           0                 3
# 434.0            84          1   4133.73           1                 2
# 36297.0           1          1    538.99           0                 4
# 9824.0          207          1   1151.14           0                 1
# 110276.0          1          1    205.99           0                 4
# 91569.0         207          1    250.18           0                 1
# 49501.0         207          1    430.36           0                 1
# 6644.0            1          1   1386.05           0                 4
# 68004.0         207          1    331.08           0                 1
#
#             Frequency_Quartile  Monetary_Quartile RFMPoints  \
# CustomerID
# 639.0                        1                  4       314
# ...

# %%
# Best Customers who's recency, frequency as well as monetary attribute is highest.
rfm_segment[rfm_segment.RFMPoints=='414'].sort_values('Monetary', ascending=False).head()
# Out:
#             Recency  Frequency  Monetary  Cluster_ID  Recency_Quartile  \
# CustomerID
# 257.0             3          1   4969.08           1                 4
# 258.0             1          1   4967.06           1                 4
# 263.0             5          1   4932.31           1                 4
# 270.0             5          1   4915.07           1                 4
# 275.0             3          1   4888.02           1                 4
#
#             Frequency_Quartile  Monetary_Quartile RFMPoints    Segment
# CustomerID
# 257.0                        1                  4       414  champions
# 258.0                        1                  4       414  champions
# 263.0                        1                  4       414  champions
# 270.0                        1                  4       414  champions
# 275.0                        1                  4       414  champions

# %%
rfm_segment[rfm_segment.RFMPoints=='314'].sort_values('Monetary', ascending=False).head()
# Out:
#             Recency  Frequency  Monetary  Cluster_ID  Recency_Quartile  \
# CustomerID
# 253.0            21          1   4984.75           1                 3
# 254.0            56          1   4982.03           1                 3
# 256.0            26          1   4971.71           1                 3
# 260.0            70          1   4960.41           1                 3
# 261.0            41          1   4958.04           1                 3
#
#             Frequency_Quartile  Monetary_Quartile RFMPoints  \
# CustomerID
# 253.0                        1                  4       314
# 254.0                        1                  4       314
# 256.0                        1                  4       314
# 260.0                        1                  4       314
# 261.0                        1                  4       314
#
#                         Segment
# CustomerID
# 253.0       Potential customers
# 254.0       Potential customers
# 256.0       Potential customers
# ...

# %%
# Almost Lost who's recency is very low
rfm_segment[rfm_segment.RFMPoints=='213'].sort_values('Monetary', ascending=False).head()
# Out:
#             Recency  Frequency  Monetary  Cluster_ID  Recency_Quartile  \
# CustomerID
# 2354.0          138          1   2169.85           1                 2
# 2363.0          150          1   2167.25           1                 2
# 2371.0          172          1   2165.72           1                 2
# 2373.0          108          1   2164.85           1                 2
# 2376.0           71          1   2162.76           1                 2
#
#             Frequency_Quartile  Monetary_Quartile RFMPoints         Segment
# CustomerID
# 2354.0                       1                  3       213  need attention
# 2363.0                       1                  3       213  need attention
# 2371.0                       1                  3       213  need attention
# 2373.0                       1                  3       213  need attention
# 2376.0                       1                  3       213  need attention

# %%
fig,axes = plt.subplots(3,1,figsize=(15,15))
sns.distplot(rfm_clean.Recency,color='Red',axlabel='Recency',ax=axes[0])
sns.distplot(rfm_clean.Frequency,color='Green',axlabel='Frequency',ax=axes[1])
sns.distplot(rfm_clean.Monetary,color='Blue',axlabel='Monetary',ax=axes[2])
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kde.py:487: RuntimeWarning: invalid value encountered in true_divide
#   binned = fast_linbin(X, a, b, gridsize) / (delta * nobs)
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:34: RuntimeWarning: invalid value encountered in double_scalars
#   FAC1 = 2*(np.pi*bw/RANGE)**2
